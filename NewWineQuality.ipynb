# %%
#Memasukkan library yang dibutuhkan seperti 
#numpy(scientific computing), pandas(menyeleraskan data untuk perbandingan dan penggabungan set data), seabor(visualisasi data secara statistik)
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier

# %%
#Menginputkan data set
data = pd.read_csv('winequalityN.csv')
data #Menampilkan data
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
#Membaca data sesuai dataframe
data = pd.read_csv("winequalityN.csv", delimiter=",")
my_data[0:12]
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   white            7.0              0.27         0.36           20.70
# 1   white            6.3              0.30         0.34            1.60
# 2   white            8.1              0.28         0.40            6.90
# 3   white            7.2              0.23         0.32            8.50
# 4   white            7.2              0.23         0.32            8.50
# 5   white            8.1              0.28         0.40            6.90
# 6   white            6.2              0.32         0.16            7.00
# 7   white            7.0              0.27         0.36           20.70
# 8   white            6.3              0.30         0.34            1.60
# 9   white            8.1              0.22         0.43            1.50
# 10  white            8.1              0.27         0.41            1.45
# 11  white            8.6              0.23         0.40            4.20
#
# ...

# %%
#Menghilangkan kolum pada target nama karena tidak berisi nilai numerik
X = data[['type','fixed acidity','volatile acidity','citric acid',
             'residual sugar','chlorides','free sulfur dioxide'	,
             'total sulfur dioxide','density','pH','sulphates','alcohol',
             'quality']].values
X[0:12]
# Out:
# array([['white', 7.0, 0.27, 0.36, 20.7, 0.045, 45.0, 170.0, 1.001, 3.0,
#         0.45, 8.8, 6],
#        ['white', 6.3, 0.3, 0.34, 1.6, 0.049, 14.0, 132.0,
#         0.9940000000000001, 3.3, 0.49, 9.5, 6],
#        ['white', 8.1, 0.28, 0.4, 6.9, 0.05, 30.0, 97.0, 0.9951, 3.26,
#         0.44, 10.1, 6],
#        ['white', 7.2, 0.23, 0.32, 8.5, 0.057999999999999996, 47.0, 186.0,
#         0.9956, 3.19, 0.4, 9.9, 6],
#        ['white', 7.2, 0.23, 0.32, 8.5, 0.057999999999999996, 47.0, 186.0,
#         0.9956, 3.19, 0.4, 9.9, 6],
#        ['white', 8.1, 0.28, 0.4, 6.9, 0.05, 30.0, 97.0, 0.9951, 3.26,
#         0.44, 10.1, 6],
#        ['white', 6.2, 0.32, 0.16, 7.0, 0.045, 30.0, 136.0, 0.9949, 3.18,
#         0.47, 9.6, 6],
#        ['white', 7.0, 0.27, 0.36, 20.7, 0.045, 45.0, 170.0, 1.001, 3.0,
#         0.45, 8.8, 6],
#        ['white', 6.3, 0.3, 0.34, 1.6, 0.049, 14.0, 132.0,
#         0.9940000000000001, 3.3, 0.49, 9.5, 6],
# ...

# %%
#Menunjukkan missing data
data.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
data['type'] = data['type'].replace("white",0)
data['type'] = data['type'].replace("red",1)

# %%
#Menghilangkan semua data yang salah
df = data.dropna(inplace=False)

# %%
#Missing data yang sudah diperbaiki
df.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#Menampilkan plot dari data alcohol
f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
sns.countplot(df['alcohol'])

f.add_subplot(1,2,2)
plt.boxplot(df['alcohol'])
plt.show()

# %%
#Menampilkan plot dari data residual sugar
f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
df['residual sugar'].plot(kind='kde')

f.add_subplot(1,2,2)
plt.boxplot(df['residual sugar'])
plt.show()

# %%
df
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        0            7.0             0.270         0.36            20.7
# 1        0            6.3             0.300         0.34             1.6
# 2        0            8.1             0.280         0.40             6.9
# 3        0            7.2             0.230         0.32             8.5
# 4        0            7.2             0.230         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 6491     1            6.8             0.620         0.08             1.9
# 6492     1            6.2             0.600         0.08             2.0
# 6494     1            6.3             0.510         0.13             2.3
# 6495     1            5.9             0.645         0.12             2.0
# 6496     1            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
X = df[['type','fixed acidity','volatile acidity','citric acid',
             'residual sugar','chlorides','free sulfur dioxide'	,
             'total sulfur dioxide','density','pH','sulphates','alcohol',
             'quality']].values
X[0:12]
# Out:
# array([[0.000e+00, 7.000e+00, 2.700e-01, 3.600e-01, 2.070e+01, 4.500e-02,
#         4.500e+01, 1.700e+02, 1.001e+00, 3.000e+00, 4.500e-01, 8.800e+00,
#         6.000e+00],
#        [0.000e+00, 6.300e+00, 3.000e-01, 3.400e-01, 1.600e+00, 4.900e-02,
#         1.400e+01, 1.320e+02, 9.940e-01, 3.300e+00, 4.900e-01, 9.500e+00,
#         6.000e+00],
#        [0.000e+00, 8.100e+00, 2.800e-01, 4.000e-01, 6.900e+00, 5.000e-02,
#         3.000e+01, 9.700e+01, 9.951e-01, 3.260e+00, 4.400e-01, 1.010e+01,
#         6.000e+00],
#        [0.000e+00, 7.200e+00, 2.300e-01, 3.200e-01, 8.500e+00, 5.800e-02,
#         4.700e+01, 1.860e+02, 9.956e-01, 3.190e+00, 4.000e-01, 9.900e+00,
#         6.000e+00],
#        [0.000e+00, 7.200e+00, 2.300e-01, 3.200e-01, 8.500e+00, 5.800e-02,
#         4.700e+01, 1.860e+02, 9.956e-01, 3.190e+00, 4.000e-01, 9.900e+00,
#         6.000e+00],
#        [0.000e+00, 8.100e+00, 2.800e-01, 4.000e-01, 6.900e+00, 5.000e-02,
# ...

# %%
#Mengisi variabel target
y = df["quality"]

y[0:12]
# Out:
# 0     6
# 1     6
# 2     6
# 3     6
# 4     6
# 5     6
# 6     6
# 7     6
# 8     6
# 9     6
# 10    5
# 11    5
# Name: quality, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
#4 parameter data yang mewakili rasio dari data set pengujian, dan random state memastikan mendapatkan pemisahan yang sama
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.3, random_state=3)

# %%
WineTree = DecisionTreeClassifier(criterion="gini", max_depth = 10)
WineTree
# Out:
# DecisionTreeClassifier(max_depth=10)

# %% [markdown]
# # MODELLING

# %%
WineTree.fit(X_trainset,y_trainset)
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
predTree = WineTree.predict(X_testset)

# %% [markdown]
# # PREDICTION

# %%
print (predTree [0:12])
print (y_testset [0:12])
# Out:
# [6 7 5 6 5 4 7 6 6 5 7 5]
# 4854    6
# 1080    7
# 5430    5
# 18      6
# 1364    5
# 2888    4
# 3293    7
# 1565    6
# 1298    6
# 5867    5
# 3382    7
# 3210    5
# Name: quality, dtype: int64

# %%
#Persentase keberhasilan
WineTree.score(X_testset, y_testset)
# Out:
# 1.0

# %% [markdown]
# # EVALUATION

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_testset, predTree))
# Out:
# DecisionTrees's Accuracy:  1.0

# %%
#Bivariate analysis antara independent variable dan dependent variable
#Melihat hubungan antara independent dan dependent
#Menggunakan pairplot
plt.figure(figsize=(10,8))
sns.pairplot(data=df, x_vars=['type','fixed acidity','volatile acidity','citric acid',
             'residual sugar','chlorides','free sulfur dioxide'	,
             'total sulfur dioxide','density','pH','sulphates','alcohol']
             , y_vars=['quality'], size=5, aspect=0.75)
plt.show()

# %% [markdown]
# # VISUALIZATION

# %%
#intallasi
# !pip install --upgrade scikit-learn==0.20.
# Out:
# Requirement already up-to-date: scikit-learn==0.20. in d:\python\lib\site-packages (0.20.0)
# ...

# %%
#installasi
conda install pydotplus
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: D:\Python
#
#   added / updated specs:
#     - pydotplus
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.9.2                |   py38haa95532_0         2.9 MB
#     graphviz-2.38              |       hfd603c8_2        29.3 MB
#     pydotplus-2.0.2            |             py_3          23 KB
#     ------------------------------------------------------------
#                                            Total:        32.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   graphviz           pkgs/main/win-64::graphviz-2.38-hfd603c8_2
#   pydotplus          pkgs/main/noarch::pydotplus-2.0.2-py_3
#
# The following packages will be UPDATED:
#
#   conda                                        4.8.3-py38_0 --> 4.9.2-py38haa95532_0
#
#
#
# ...
#
# ...

# %%
# !apt-get -qq install -y graphviz && pip install -q pydotplus
from sklearn.externals.six import StringIO
import pydotplus
import matplotlib.image as mpimg
from sklearn import tree
# %matplotlib inline
# Out:
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.

# %%
dot_data = StringIO()
filename = "winetree.png"
featureNames = my_data.columns[0:5]
targetNames = my_data["Wine"].unique().tolist()
out=tree.export_graphviz(drugTree,feature_names=featureNames, out_file=dot_data, class_names= np.unique(y_trainset), filled=True,  special_characters=True,rotate=False)  
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png(filename)
img = mpimg.imread(filename)
plt.figure(figsize=(100, 200))
plt.imshow(img,interpolation='nearest')
